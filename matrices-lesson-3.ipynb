# %% [markdown]
# # Matrices in R

# %% [markdown]
# **Basketball Dataset**

# %%
#Dear Student,
#
#Welcome to the world of Basketball Data!
#I'm sure you will enjoy this section of the R Programming course.
#
#Instructions for this dataset:
# Simply select ALL the lines in this script by pressing 
# CTRL+A on Windows or CMND+A on a Mac and execute them
# Once you have executed the commands the following objects
# will be created:
# Matrices:
# - FieldGoalAttempts
# - FieldGoals
# - Games
# - MinutesPlayed
# - Salary
# Vectors:
# - Players
# - Seasons
#We will go understand these inside the course.
#
#Sincerely,
#Kirill Eremenko
#www.superdatascience.com

#Copyright: These datasets were prepared using publicly available data.
#           However, theses scripts are subject to Copyright Laws. 
#           If you wish to use these R scripts outside of the R Programming Course
#           by Kirill Eremenko, you may do so by referencing www.superdatascience.com in your work.

#Comments:
#Seasons are labeled based on the first year in the season
#E.g. the 2012-2013 season is preseneted as simply 2012

#Notes and Corrections to the data:
#Kevin Durant: 2006 - College Data Used
#Kevin Durant: 2005 - Proxied With 2006 Data
#Derrick Rose: 2012 - Did Not Play
#Derrick Rose: 2007 - College Data Used
#Derrick Rose: 2006 - Proxied With 2007 Data
#Derrick Rose: 2005 - Proxied With 2007 Data

#Seasons
Seasons <- c("2005","2006","2007","2008","2009","2010","2011","2012","2013","2014")

#Players
Players <- c("KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade")

#Salaries
KobeBryant_Salary <- c(15946875,17718750,19490625,21262500,23034375,24806250,25244493,27849149,30453805,23500000)
JoeJohnson_Salary <- c(12000000,12744189,13488377,14232567,14976754,16324500,18038573,19752645,21466718,23180790)
LeBronJames_Salary <- c(4621800,5828090,13041250,14410581,15779912,14500000,16022500,17545000,19067500,20644400)
CarmeloAnthony_Salary <- c(3713640,4694041,13041250,14410581,15779912,17149243,18518574,19450000,22407474,22458000)
DwightHoward_Salary <- c(4493160,4806720,6061274,13758000,15202590,16647180,18091770,19536360,20513178,21436271)
ChrisBosh_Salary <- c(3348000,4235220,12455000,14410581,15779912,14500000,16022500,17545000,19067500,20644400)
ChrisPaul_Salary <- c(3144240,3380160,3615960,4574189,13520500,14940153,16359805,17779458,18668431,20068563)
KevinDurant_Salary <- c(0,0,4171200,4484040,4796880,6053663,15506632,16669630,17832627,18995624)
DerrickRose_Salary <- c(0,0,0,4822800,5184480,5546160,6993708,16402500,17632688,18862875)
DwayneWade_Salary <- c(3031920,3841443,13041250,14410581,15779912,14200000,15691000,17182000,18673000,15000000)
#Matrix
Salary <- rbind(KobeBryant_Salary, JoeJohnson_Salary, LeBronJames_Salary, CarmeloAnthony_Salary, DwightHoward_Salary, ChrisBosh_Salary, ChrisPaul_Salary, KevinDurant_Salary, DerrickRose_Salary, DwayneWade_Salary)
rm(KobeBryant_Salary, JoeJohnson_Salary, CarmeloAnthony_Salary, DwightHoward_Salary, ChrisBosh_Salary, LeBronJames_Salary, ChrisPaul_Salary, DerrickRose_Salary, DwayneWade_Salary, KevinDurant_Salary)
colnames(Salary) <- Seasons
rownames(Salary) <- Players

#Games 
KobeBryant_G <- c(80,77,82,82,73,82,58,78,6,35)
JoeJohnson_G <- c(82,57,82,79,76,72,60,72,79,80)
LeBronJames_G <- c(79,78,75,81,76,79,62,76,77,69)
CarmeloAnthony_G <- c(80,65,77,66,69,77,55,67,77,40)
DwightHoward_G <- c(82,82,82,79,82,78,54,76,71,41)
ChrisBosh_G <- c(70,69,67,77,70,77,57,74,79,44)
ChrisPaul_G <- c(78,64,80,78,45,80,60,70,62,82)
KevinDurant_G <- c(35,35,80,74,82,78,66,81,81,27)
DerrickRose_G <- c(40,40,40,81,78,81,39,0,10,51)
DwayneWade_G <- c(75,51,51,79,77,76,49,69,54,62)
#Matrix
Games <- rbind(KobeBryant_G, JoeJohnson_G, LeBronJames_G, CarmeloAnthony_G, DwightHoward_G, ChrisBosh_G, ChrisPaul_G, KevinDurant_G, DerrickRose_G, DwayneWade_G)
rm(KobeBryant_G, JoeJohnson_G, CarmeloAnthony_G, DwightHoward_G, ChrisBosh_G, LeBronJames_G, ChrisPaul_G, DerrickRose_G, DwayneWade_G, KevinDurant_G)
colnames(Games) <- Seasons
rownames(Games) <- Players

#Minutes Played
KobeBryant_MP <- c(3277,3140,3192,2960,2835,2779,2232,3013,177,1207)
JoeJohnson_MP <- c(3340,2359,3343,3124,2886,2554,2127,2642,2575,2791)
LeBronJames_MP <- c(3361,3190,3027,3054,2966,3063,2326,2877,2902,2493)
CarmeloAnthony_MP <- c(2941,2486,2806,2277,2634,2751,1876,2482,2982,1428)
DwightHoward_MP <- c(3021,3023,3088,2821,2843,2935,2070,2722,2396,1223)
ChrisBosh_MP <- c(2751,2658,2425,2928,2526,2795,2007,2454,2531,1556)
ChrisPaul_MP <- c(2808,2353,3006,3002,1712,2880,2181,2335,2171,2857)
KevinDurant_MP <- c(1255,1255,2768,2885,3239,3038,2546,3119,3122,913)
DerrickRose_MP <- c(1168,1168,1168,3000,2871,3026,1375,0,311,1530)
DwayneWade_MP <- c(2892,1931,1954,3048,2792,2823,1625,2391,1775,1971)
#Matrix
MinutesPlayed <- rbind(KobeBryant_MP, JoeJohnson_MP, LeBronJames_MP, CarmeloAnthony_MP, DwightHoward_MP, ChrisBosh_MP, ChrisPaul_MP, KevinDurant_MP, DerrickRose_MP, DwayneWade_MP)
rm(KobeBryant_MP, JoeJohnson_MP, CarmeloAnthony_MP, DwightHoward_MP, ChrisBosh_MP, LeBronJames_MP, ChrisPaul_MP, DerrickRose_MP, DwayneWade_MP, KevinDurant_MP)
colnames(MinutesPlayed) <- Seasons
rownames(MinutesPlayed) <- Players

#Field Goals
KobeBryant_FG <- c(978,813,775,800,716,740,574,738,31,266)
JoeJohnson_FG <- c(632,536,647,620,635,514,423,445,462,446)
LeBronJames_FG <- c(875,772,794,789,768,758,621,765,767,624)
CarmeloAnthony_FG <- c(756,691,728,535,688,684,441,669,743,358)
DwightHoward_FG <- c(468,526,583,560,510,619,416,470,473,251)
ChrisBosh_FG <- c(549,543,507,615,600,524,393,485,492,343)
ChrisPaul_FG <- c(407,381,630,631,314,430,425,412,406,568)
KevinDurant_FG <- c(306,306,587,661,794,711,643,731,849,238)
DerrickRose_FG <- c(208,208,208,574,672,711,302,0,58,338)
DwayneWade_FG <- c(699,472,439,854,719,692,416,569,415,509)
#Matrix
FieldGoals <- rbind(KobeBryant_FG, JoeJohnson_FG, LeBronJames_FG, CarmeloAnthony_FG, DwightHoward_FG, ChrisBosh_FG, ChrisPaul_FG, KevinDurant_FG, DerrickRose_FG, DwayneWade_FG)
rm(KobeBryant_FG, JoeJohnson_FG, LeBronJames_FG, CarmeloAnthony_FG, DwightHoward_FG, ChrisBosh_FG, ChrisPaul_FG, KevinDurant_FG, DerrickRose_FG, DwayneWade_FG)
colnames(FieldGoals) <- Seasons
rownames(FieldGoals) <- Players

#Field Goal Attempts
KobeBryant_FGA <- c(2173,1757,1690,1712,1569,1639,1336,1595,73,713)
JoeJohnson_FGA <- c(1395,1139,1497,1420,1386,1161,931,1052,1018,1025)
LeBronJames_FGA <- c(1823,1621,1642,1613,1528,1485,1169,1354,1353,1279)
CarmeloAnthony_FGA <- c(1572,1453,1481,1207,1502,1503,1025,1489,1643,806)
DwightHoward_FGA <- c(881,873,974,979,834,1044,726,813,800,423)
ChrisBosh_FGA <- c(1087,1094,1027,1263,1158,1056,807,907,953,745)
ChrisPaul_FGA <- c(947,871,1291,1255,637,928,890,856,870,1170)
KevinDurant_FGA <- c(647,647,1366,1390,1668,1538,1297,1433,1688,467)
DerrickRose_FGA <- c(436,436,436,1208,1373,1597,695,0,164,835)
DwayneWade_FGA <- c(1413,962,937,1739,1511,1384,837,1093,761,1084)
#Matrix
FieldGoalAttempts <- rbind(KobeBryant_FGA, JoeJohnson_FGA, LeBronJames_FGA, CarmeloAnthony_FGA, DwightHoward_FGA, ChrisBosh_FGA, ChrisPaul_FGA, KevinDurant_FGA, DerrickRose_FGA, DwayneWade_FGA)
rm(KobeBryant_FGA, JoeJohnson_FGA, LeBronJames_FGA, CarmeloAnthony_FGA, DwightHoward_FGA, ChrisBosh_FGA, ChrisPaul_FGA, KevinDurant_FGA, DerrickRose_FGA, DwayneWade_FGA)
colnames(FieldGoalAttempts) <- Seasons
rownames(FieldGoalAttempts) <- Players

#Points
KobeBryant_PTS <- c(2832,2430,2323,2201,1970,2078,1616,2133,83,782)
JoeJohnson_PTS <- c(1653,1426,1779,1688,1619,1312,1129,1170,1245,1154)
LeBronJames_PTS <- c(2478,2132,2250,2304,2258,2111,1683,2036,2089,1743)
CarmeloAnthony_PTS <- c(2122,1881,1978,1504,1943,1970,1245,1920,2112,966)
DwightHoward_PTS <- c(1292,1443,1695,1624,1503,1784,1113,1296,1297,646)
ChrisBosh_PTS <- c(1572,1561,1496,1746,1678,1438,1025,1232,1281,928)
ChrisPaul_PTS <- c(1258,1104,1684,1781,841,1268,1189,1186,1185,1564)
KevinDurant_PTS <- c(903,903,1624,1871,2472,2161,1850,2280,2593,686)
DerrickRose_PTS <- c(597,597,597,1361,1619,2026,852,0,159,904)
DwayneWade_PTS <- c(2040,1397,1254,2386,2045,1941,1082,1463,1028,1331)
#Matrix
Points <- rbind(KobeBryant_PTS, JoeJohnson_PTS, LeBronJames_PTS, CarmeloAnthony_PTS, DwightHoward_PTS, ChrisBosh_PTS, ChrisPaul_PTS, KevinDurant_PTS, DerrickRose_PTS, DwayneWade_PTS)
rm(KobeBryant_PTS, JoeJohnson_PTS, LeBronJames_PTS, CarmeloAnthony_PTS, DwightHoward_PTS, ChrisBosh_PTS, ChrisPaul_PTS, KevinDurant_PTS, DerrickRose_PTS, DwayneWade_PTS)
colnames(Points) <- Seasons
rownames(Points) <- Players

# %%
Salary
# Out:
#                2005     2006     2007     2008     2009     2010     2011
# KobeBryant     15946875 17718750 19490625 21262500 23034375 24806250 25244493
# JoeJohnson     12000000 12744189 13488377 14232567 14976754 16324500 18038573
# LeBronJames     4621800  5828090 13041250 14410581 15779912 14500000 16022500
# CarmeloAnthony  3713640  4694041 13041250 14410581 15779912 17149243 18518574
# DwightHoward    4493160  4806720  6061274 13758000 15202590 16647180 18091770
# ChrisBosh       3348000  4235220 12455000 14410581 15779912 14500000 16022500
# ChrisPaul       3144240  3380160  3615960  4574189 13520500 14940153 16359805
# KevinDurant           0        0  4171200  4484040  4796880  6053663 15506632
# DerrickRose           0        0        0  4822800  5184480  5546160  6993708
# DwayneWade      3031920  3841443 13041250 14410581 15779912 14200000 15691000
#                2012     2013     2014
# KobeBryant     27849149 30453805 23500000
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **If we want to call the element 0 using the Vector approach. If we type A[4] how will R know which element to return, it will return the whole column. If we type A[3], then R will return the entire row. To call an element from a matrix in R we type X[A,B] where X is the Matrix name, A is the number of row where our element is, and B is the number of column of our element**

# %% [markdown]
# **To take the whole row out of the Matrix in R, we leave the column field. For example, if we want to return the  entire first row, we'll type A[1, ] where A is name of matrix and 1 is number of the row we want to return**
#
# **To take the whole column out of the Matrix in R, we leave the row field. For example, if we want to return the  entire fifth column, we'll type A[5, ] where A is name of matrix and 5 is number of the column we want to return**

# %% [markdown]
# ## Ways to build a Matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The first way to build a matrix is by using **Matrix()** function. It is uncommon to use this fucntion as it bends the values. If we use **Matrix()** on alpphabets, it will bend and fit them as shown above.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The second way to build a matrix is to use a function called **rbind()**. It takes a first vector and attaches it in Row 1 and then it the second vector and attaches it to the second row.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The second function is **cbind()** . It takes the vector and divides it and stacks it in columns as opposed to the rbind() function which did the same for rows.

# %%
?matrix() #use this to learn more about matrices in R

# %% [markdown]
# R defines matrix function as
#
# **matrix(data = NA, nrow = 1, ncol = 1, byrow = FALSE,
#        dimnames = NULL)**

# %% [markdown]
# nrow= number of rows ,  ncol= number of column, byrow= if we want to sort the matrix by rows

# %%
#Let's make a matrix()

# %%
c <- 1:20 #storing the value from 1 to 20 in c

# %%
M<- matrix(data=c,4 , 5) #storing the value of matrix into a parameter
M
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 1    5     9   13   17
# [2,] 2    6    10   14   18
# [3,] 3    7    11   15   19
# [4,] 4    8    12   16   20

# %%
#To call an element out of the matrix.

#Let's say we want to call the number '20' out of the matrix

M[4,5]
# Out:
# [1] 20

# %%
#To bend the data by rows we can set the value of 'byrow=T'

Z<- matrix(data=c, nrow = 4 , ncol=5, byrow= T)
Z
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,]  1    2    3    4    5
# [2,]  6    7    8    9   10
# [3,] 11   12   13   14   15
# [4,] 16   17   18   19   20

# %%
#to call '10' out of this matrix

Z[2,5]
# Out:
# [1] 10

# %%
# we can see that if we declare a matrix that doesn't fit the data, then matrix() function will cut the data

M2<-matrix(data=c, nrow= 4, ncol= 4)
M2
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1    5     9   13
# [2,] 2    6    10   14
# [3,] 3    7    11   15
# [4,] 4    8    12   16

# %%
# to use rbind()

r1<- c("How", "Are", "You")
r2<- c("I", "Am", "Fine")
r3<- c(1, 2, 3)

rbind(r1,r2,r3)
# Out:
#    [,1] [,2] [,3]
# r1 How  Are  You
# r2 I    Am   Fine
# r3 1    2    3

# %%
# rbind()

r1<- c("Hello", "How", "Are", "You")
r2<- c("I", "Am", "Fine")
r3<- c(1, 2, 3)

rbind(r1,r2,r3)
# Out:
# Warning message in rbind(r1, r2, r3):
# “number of columns of result is not a multiple of vector length (arg 2)”
#    [,1]  [,2] [,3] [,4]
# r1 Hello How  Are  You
# r2 I     Am   Fine I
# r3 1     2    3    1

# %% [markdown]
# We can see if the number of rows doesn't matches number of columns, rbind() will recycle the element as shown in r2 and r3.

# %%
#To use cbind()

c1<- c("How", "Are", "You")
c2<- c("I", "Am", "Fine")
c3<- c(1, 2, 3)

cbind(c1,c2,c3)
# Out:
#      c1  c2   c3
# [1,] How I    1
# [2,] Are Am   2
# [3,] You Fine 3

# %% [markdown]
# ## Naming Dimensions in Matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If we have matrix where the columns are named as above. So how we'll call the element '0' out of the matrix.
#
# To call out the element from a named matrix like the one above, we use the row number and column name.
#
# **A[3,"S"]** since it is name we have to use double quoatation marks for S.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Suppose if the rows are also named as above. To call out the number '0' from the matrix we'll type.
#
# **A["Best","S"]**
#
# or we can also use
#
# **A["Best", 4]**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Suppose we have a named vector as above. To call out the number '0' we can either type V[4] where 4 is index of the element or we can type V["d"]

# %% [markdown]
# ## Colnames() and Rownames() in R

# %% [markdown]
# Let's create a named vector

# %%
#Declaring a vector 'albus' and giving it value

albus<- 1:4

# %%
albus
# Out:
# [1] 1 2 3 4

# %%
#If we try to check if albus is a named vector

names(albus)
# Out:
# NULL

# %% [markdown]
# We get 'Null' meaning albus is not a named vector.

# %%
# To give name, we can actually pass the value of names to the names() function as

names(albus)<- c("Hufflepuff","Slytherin", "Ravenclaw", "Gryffindor")

# %% [markdown]
# Now if we run 'albus' we'll see that the names have been assigned

# %%
albus
# Out:
# Hufflepuff  Slytherin  Ravenclaw Gryffindor
#          1          2          3          4

# %%
#To clear names from a named vector just pass 'NULL' to names() function

names(albus)<- NULL
albus
# Out:
# [1] 1 2 3 4

# %% [markdown]
# We can see that now there are no names

# %% [markdown]
# **A different way to use replicate function is to use each**
#
# for example:- rep(c(1,3,4), 2) will give result like 1 2 3 4 1 2 3 4
#
# while rep(c(1,2,3,4), each=2) will give result like 1 1 2 2 3 3 4 4

# %%
# Naming matrix dimensions

# %%
#Creating a temporary vector

tmp.vec <- rep(c("a","b","c"), each=3)
tmp.vec
# Out:
# [1] "a" "a" "a" "b" "b" "b" "c" "c" "c"

# %%
#as there are 9 element so matrix will be 3x3

maetrix <- matrix(tmp.vec, 3,3,) #where nrow=3,ncol=3
maetrix
# Out:
#      [,1] [,2] [,3]
# [1,] a    b    c
# [2,] a    b    c
# [3,] a    b    c

# %%
#If we try to find the row names

rownames(maetrix)
# Out:
# NULL

# %% [markdown]
# We get 'NULL' which means this matrix doesn't have any rownames

# %%
#We can give rownames by passing rownames as a vector

rownames(maetrix)<- c("Just","A","Name")
maetrix
# Out:
#      [,1] [,2] [,3]
# Just a    b    c
# A    a    b    c
# Name a    b    c

# %%
#To give column names

colnames(maetrix)<- c("A", "B","C")
maetrix
# Out:
#      A B C
# Just a b c
# A    a b c
# Name a b c

# %%
#We can call out a value by

maetrix["Just", "B"]
# Out:
# [1] "b"

# %%
#we can also replace that element as

maetrix["Just", "B"]<- 9
maetrix
# Out:
#      A B C
# Just a 9 c
# A    a b c
# Name a b c

# %% [markdown]
# **To get rid of the Rownames or Column names, simply pass NULL value into them**
#
# example: rownames(maetrix)<- NUL

# %% [markdown]
# or colnames(maetrix)<- NULL

# %% [markdown]
# ## Matrix Operations in R

# %%
# Let's recall the matrix that we made in the start of this lesson

Games
# Out:
#                2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# KobeBryant     80   77   82   82   73   82   58   78    6   35
# JoeJohnson     82   57   82   79   76   72   60   72   79   80
# LeBronJames    79   78   75   81   76   79   62   76   77   69
# CarmeloAnthony 80   65   77   66   69   77   55   67   77   40
# DwightHoward   82   82   82   79   82   78   54   76   71   41
# ChrisBosh      70   69   67   77   70   77   57   74   79   44
# ChrisPaul      78   64   80   78   45   80   60   70   62   82
# KevinDurant    35   35   80   74   82   78   66   81   81   27
# DerrickRose    40   40   40   81   78   81   39    0   10   51
# DwayneWade     75   51   51   79   77   76   49   69   54   62

# %%
#Checking the rownames

rownames(Games)
# Out:
#  [1] "KobeBryant"     "JoeJohnson"     "LeBronJames"    "CarmeloAnthony"
#  [5] "DwightHoward"   "ChrisBosh"      "ChrisPaul"      "KevinDurant"
#  [9] "DerrickRose"    "DwayneWade"

# %%
colnames(Games)
# Out:
#  [1] "2005" "2006" "2007" "2008" "2009" "2010" "2011" "2012" "2013" "2014"

# %%
#We can also print a value as

Games["LeBronJames", "2012"]
# Out:
# [1] 76

# %%
#Let's try another matrix

FieldGoals
# Out:
#                2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# KobeBryant     978  813  775  800  716  740  574  738   31  266
# JoeJohnson     632  536  647  620  635  514  423  445  462  446
# LeBronJames    875  772  794  789  768  758  621  765  767  624
# CarmeloAnthony 756  691  728  535  688  684  441  669  743  358
# DwightHoward   468  526  583  560  510  619  416  470  473  251
# ChrisBosh      549  543  507  615  600  524  393  485  492  343
# ChrisPaul      407  381  630  631  314  430  425  412  406  568
# KevinDurant    306  306  587  661  794  711  643  731  849  238
# DerrickRose    208  208  208  574  672  711  302    0   58  338
# DwayneWade     699  472  439  854  719  692  416  569  415  509

# %%
# Matrix Division

# %%
#let's say if we want to find the field goals scored/game. we can simply do

FieldGoals/Games
# Out:
#                2005      2006      2007      2008      2009      2010
# KobeBryant     12.225000 10.558442  9.451220  9.756098  9.808219 9.024390
# JoeJohnson      7.707317  9.403509  7.890244  7.848101  8.355263 7.138889
# LeBronJames    11.075949  9.897436 10.586667  9.740741 10.105263 9.594937
# CarmeloAnthony  9.450000 10.630769  9.454545  8.106061  9.971014 8.883117
# DwightHoward    5.707317  6.414634  7.109756  7.088608  6.219512 7.935897
# ChrisBosh       7.842857  7.869565  7.567164  7.987013  8.571429 6.805195
# ChrisPaul       5.217949  5.953125  7.875000  8.089744  6.977778 5.375000
# KevinDurant     8.742857  8.742857  7.337500  8.932432  9.682927 9.115385
# DerrickRose     5.200000  5.200000  5.200000  7.086420  8.615385 8.777778
# DwayneWade      9.320000  9.254902  8.607843 10.810127  9.337662 9.105263
#                2011      2012      2013      2014
# KobeBryant      9.896552  9.461538  5.166667 7.600000
# JoeJohnson      7.050000  6.180556  5.848101 5.575000
# ...

# %%
#If we try to round that up. We get

round(FieldGoals/Games, digits=1)
# Out:
#                2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# KobeBryant     12.2 10.6  9.5  9.8  9.8 9.0   9.9  9.5  5.2 7.6
# JoeJohnson      7.7  9.4  7.9  7.8  8.4 7.1   7.0  6.2  5.8 5.6
# LeBronJames    11.1  9.9 10.6  9.7 10.1 9.6  10.0 10.1 10.0 9.0
# CarmeloAnthony  9.4 10.6  9.5  8.1 10.0 8.9   8.0 10.0  9.6 8.9
# DwightHoward    5.7  6.4  7.1  7.1  6.2 7.9   7.7  6.2  6.7 6.1
# ChrisBosh       7.8  7.9  7.6  8.0  8.6 6.8   6.9  6.6  6.2 7.8
# ChrisPaul       5.2  6.0  7.9  8.1  7.0 5.4   7.1  5.9  6.5 6.9
# KevinDurant     8.7  8.7  7.3  8.9  9.7 9.1   9.7  9.0 10.5 8.8
# DerrickRose     5.2  5.2  5.2  7.1  8.6 8.8   7.7  NaN  5.8 6.6
# DwayneWade      9.3  9.3  8.6 10.8  9.3 9.1   8.5  8.2  7.7 8.2

# %% [markdown]
# It shows how many field goals each player scored per game

# %%
#Let's try to find how many minutes each player played per season

round(MinutesPlayed/Games)
# Out:
#                2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# KobeBryant     41   41   39   36   39   34   38    39  30   34
# JoeJohnson     41   41   41   40   38   35   35    37  33   35
# LeBronJames    43   41   40   38   39   39   38    38  38   36
# CarmeloAnthony 37   38   36   34   38   36   34    37  39   36
# DwightHoward   37   37   38   36   35   38   38    36  34   30
# ChrisBosh      39   39   36   38   36   36   35    33  32   35
# ChrisPaul      36   37   38   38   38   36   36    33  35   35
# KevinDurant    36   36   35   39   40   39   39    39  39   34
# DerrickRose    29   29   29   37   37   37   35   NaN  31   30
# DwayneWade     39   38   38   39   36   37   33    35  33   32

# %%
# These are the two matrices that we made ealier in this chapter
M
M2
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 1    5     9   13   17
# [2,] 2    6    10   14   18
# [3,] 3    7    11   15   19
# [4,] 4    8    12   16   20
#      [,1] [,2] [,3] [,4]
# [1,] 1    5     9   13
# [2,] 2    6    10   14
# [3,] 3    7    11   15
# [4,] 4    8    12   16

# %%
#Let's try Matrix Addition
M  #The matrix on which addition is done
M+M #We cannot add M with M2 as the dimensions of both matrices are different and we'll get an error
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 1    5     9   13   17
# [2,] 2    6    10   14   18
# [3,] 3    7    11   15   19
# [4,] 4    8    12   16   20
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 2    10   18   26   34
# [2,] 4    12   20   28   36
# [3,] 6    14   22   30   38
# [4,] 8    16   24   32   40

# %%
#Matrix Multiplication
M    #The matrix on which multiplication is done
M*M
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 1    5     9   13   17
# [2,] 2    6    10   14   18
# [3,] 3    7    11   15   19
# [4,] 4    8    12   16   20
#      [,1] [,2] [,3] [,4] [,5]
# [1,]  1   25    81  169  289
# [2,]  4   36   100  196  324
# [3,]  9   49   121  225  361
# [4,] 16   64   144  256  400

# %% [markdown]
# ## Visualizing with Matplot()

# %% [markdown]
# Plot Columns of Matrices
#
# Plot the columns of one matrix against the columns of another.
#
# Keywords
#     hplot, aplot, array
#
# Usage
#
# matplot(x, y, type = "p", lty = 1:5, lwd = 1, lend = par("lend"),
#         pch = NULL,
#         col = 1:6, cex = NULL, bg = NA,
#         xlab = NULL, ylab = NULL, xlim = NULL, ylim = NULL,
#         log = "", …, add = FALSE, verbose = getOption("verbose"))
#
# matpoints(x, y, type = "p", lty = 1:5, lwd = 1, pch = NULL,
#           col = 1:6, …)
#
# matlines (x, y, type = "l", lty = 1:5, lwd = 1, pch = NULL,
#           col = 1:6, …)
#
# Arguments
#
# x,y
#
#     vectors or matrices of data for plotting. The number of rows should match. If one of them are missing, the other is taken as y and an x vector of 1:n is used. Missing values (NAs) are allowed.
# type
#
#     character string (length 1 vector) or vector of 1-character strings indicating the type of plot for each column of y, see plot for all possible types. The first character of type defines the first plot, the second character the second, etc. Characters in type are cycled through; e.g., "pl" alternately plots points and lines.
# lty,lwd,lend
#
#     vector of line types, widths, and end styles. The first element is for the first column, the second element for the second column, etc., even if lines are not plotted for all columns. Line types will be used cyclically until all plots are drawn.
# pch
#
#     character string or vector of 1-characters or integers for plotting characters, see points. The first character is the plotting-character for the first plot, the second for the second, etc. The default is the digits (1 through 9, 0) then the lowercase and uppercase letters.
# col
#
#     vector of colors. Colors are used cyclically.
# cex
#
#     vector of character expansion sizes, used cyclically. This works as a multiple of par("cex"). NULL is equivalent to 1.0.
# bg
#
#     vector of background (fill) colors for the open plot symbols given by pch = 21:25 as in points. The default NA corresponds to the one of the underlying function plot.xy.
# xlab, ylab
#
#     titles for x and y axes, as in plot.
# xlim, ylim
#
#     ranges of x and y axes, as in plot.
# log, …
#
#     Graphical parameters (see par) and any further arguments of plot, typically plot.default, may also be supplied as arguments to this function; even panel.first etc now work. Hence, the high-level graphics control arguments described under par and the arguments to title may be supplied to this function.
# add
#
#     logical. If TRUE, plots are added to current one, using points and lines.
# verbose
#
#     logical. If TRUE, write one line of what is done.
#
# Details
#
# Points involving missing values are not plotted.
#
# The first column of x is plotted against the first column of y, the second column of x against the second column of y, etc. If one matrix has fewer columns, plotting will cycle back through the columns again. (In particular, either x or y may be a vector, against which all columns of the other argument will be plotted.)
#
# The first element of col, cex, lty, lwd is used to plot the axes as well as the first line.
#
# Because plotting symbols are drawn with lines and because these functions may be changing the line style, you should probably specify lty = 1 when using plotting symbols.
#
# Side Effects
#
# Function matplot generates a new plot; matpoints and matlines add to the current one.

# %%
# If we want to plot FieldGoals we cannot simply write matlpot(FieldGoals)

#It's because matplot function plots columns one by one

#For the current matrix will plot each colums and here years are arranged in colums, it'll plot years

#we don't want to plot years, we want to plot year-wise performance of players

# %%
FieldGoals
# Out:
#                2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# KobeBryant     978  813  775  800  716  740  574  738   31  266
# JoeJohnson     632  536  647  620  635  514  423  445  462  446
# LeBronJames    875  772  794  789  768  758  621  765  767  624
# CarmeloAnthony 756  691  728  535  688  684  441  669  743  358
# DwightHoward   468  526  583  560  510  619  416  470  473  251
# ChrisBosh      549  543  507  615  600  524  393  485  492  343
# ChrisPaul      407  381  630  631  314  430  425  412  406  568
# KevinDurant    306  306  587  661  794  711  643  731  849  238
# DerrickRose    208  208  208  574  672  711  302    0   58  338
# DwayneWade     699  472  439  854  719  692  416  569  415  509

# %%
#So we have to interchange rows and columns. we can do this by using transpose function

t(FieldGoals)
# Out:
#      KobeBryant JoeJohnson LeBronJames CarmeloAnthony DwightHoward ChrisBosh
# 2005 978        632        875         756            468          549
# 2006 813        536        772         691            526          543
# 2007 775        647        794         728            583          507
# 2008 800        620        789         535            560          615
# 2009 716        635        768         688            510          600
# 2010 740        514        758         684            619          524
# 2011 574        423        621         441            416          393
# 2012 738        445        765         669            470          485
# 2013  31        462        767         743            473          492
# 2014 266        446        624         358            251          343
#      ChrisPaul KevinDurant DerrickRose DwayneWade
# 2005 407       306         208         699
# 2006 381       306         208         472
# 2007 630       587         208         439
# ...

# %%
# Now plotting the matrix

matplot(FieldGoals)

# %% [markdown]
# Although we can deduce trends from this graph there isn't much to deduce. Let's try to make it readable

# %%
matplot(t(FieldGoals), type="b", pch= 15:18,col=c(1:4,6))

#Type means the type of plot we want, b means both lines and point which we can see it it.
#pch means "Plotting-Character".
#col means color

# %% [markdown]
# As we can see that our graph makes more sense now, but there is still one more thing missing. We don't know what this graph means by seeing it. We need a legend. To do this we need a legend function.

# %%
#To show the legend, we can simply type:

matplot(t(FieldGoals), type="b", pch= 15:18,col=c(1:4,6))
legend("bottomleft", inset= 0.01, legend=Players, col=c(1:4,6),pch=15:18, horiz= F)

# %%
#Let's try to visualize another datsaet

matplot(t(FieldGoals/ FieldGoalAttempts), type="b", pch= 15:18,col=c(1:4,6))
legend("bottomleft", inset= 0.01, legend=Players, col=c(1:4,6),pch=15:18, horiz= F)

# %% [markdown]
# We can see the accuracy of the players as depicted in the graph above.

# %% [markdown]
# ## Subsetting

# %% [markdown]
# Substetting is a very important topic in R.

# %%
#let's create a vector 

x<- c("a","b","c","d","e")
x

x[c(1,5)] #printing the value at 1st and 5th position in our vector
x[1] #we can also do that to print the value at the first position in our vector
# Out:
# [1] "a" "b" "c" "d" "e"
# [1] "a" "e"
# [1] "a"

# %%
#Now let's talk about the matrix 'Games' Supoose if we wanted to print the value only for 5 years.

#we can do that as
Games #original matrix
Games[1:3,6:10] #we can also see that subset of matrix is also a matrix
# Out:
#                2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# KobeBryant     80   77   82   82   73   82   58   78    6   35
# JoeJohnson     82   57   82   79   76   72   60   72   79   80
# LeBronJames    79   78   75   81   76   79   62   76   77   69
# CarmeloAnthony 80   65   77   66   69   77   55   67   77   40
# DwightHoward   82   82   82   79   82   78   54   76   71   41
# ChrisBosh      70   69   67   77   70   77   57   74   79   44
# ChrisPaul      78   64   80   78   45   80   60   70   62   82
# KevinDurant    35   35   80   74   82   78   66   81   81   27
# DerrickRose    40   40   40   81   78   81   39    0   10   51
# DwayneWade     75   51   51   79   77   76   49   69   54   62
#             2010 2011 2012 2013 2014
# KobeBryant  82   58   78    6   35
# JoeJohnson  72   60   72   79   80
# LeBronJames 79   62   76   77   69

# %%
# Now suppose that we only want to compare two players. To do that we can type

Games[c(1,10),] #leaving the blank for the column vector
# Out:
#            2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# KobeBryant 80   77   82   82   73   82   58   78    6   35
# DwayneWade 75   51   51   79   77   76   49   69   54   62

# %%
#Now if we want to compare two years of all the players. Years are the columns. We can type

Games
Games[,c("2008","2009")] #we leave the row as it is. Also we can call element by their names.
# Out:
#                2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# KobeBryant     80   77   82   82   73   82   58   78    6   35
# JoeJohnson     82   57   82   79   76   72   60   72   79   80
# LeBronJames    79   78   75   81   76   79   62   76   77   69
# CarmeloAnthony 80   65   77   66   69   77   55   67   77   40
# DwightHoward   82   82   82   79   82   78   54   76   71   41
# ChrisBosh      70   69   67   77   70   77   57   74   79   44
# ChrisPaul      78   64   80   78   45   80   60   70   62   82
# KevinDurant    35   35   80   74   82   78   66   81   81   27
# DerrickRose    40   40   40   81   78   81   39    0   10   51
# DwayneWade     75   51   51   79   77   76   49   69   54   62
#                2008 2009
# KobeBryant     82   73
# JoeJohnson     79   76
# LeBronJames    81   76
# CarmeloAnthony 66   69
# DwightHoward   79   82
# ChrisBosh      77   70
# ChrisPaul      78   45
# KevinDurant    74   82
# DerrickRose    81   78
# DwayneWade     79   77

# %%
#Let's call an element 

is.matrix(Games[,c("2008","2009")])
# Out:
# [1] TRUE

# %%
#let's call a value 

Games[1,]
# Out:
# 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
#   80   77   82   82   73   82   58   78    6   35

# %%
#if we want to check that above result is a matrix

is.matrix(Games[1,])
# Out:
# [1] FALSE

# %% [markdown]
# we get FALSE because it is a vector. R is guessing that since we want one-dimensional object from matrix, most probably it's a vector.

# %%
#R would normally drop the dimension when it's only one.

Games[1,, drop=F]
# Out:
#            2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# KobeBryant 80   77   82   82   73   82   58   78   6    35

# %% [markdown]
# Here we'll get a matrix

# %% [markdown]
# Whenever we use square brackets, R is guessing what we want. If we don't want R to guess then don't forget to use "drop" and set it to FALSE.

# %% [markdown]
# ## Visualizing Subsets

# %%
#Let's say we don't want to visualize entire set but only 1st 3 players

#Let's try to visualize "Minutes Played"

Data<- MinutesPlayed[1:3,] #only three rows
matplot(t(Data), type="b", pch= 15:18,col=c(1:4,6))

#Let's try to make a legend only for first three players

legend("bottomleft", inset= 0.01, legend=Players [1:3], col=c(1:4,6),pch=15:18, horiz= F)

# %%
#We can also plot the above graph by assigning value into "Data" using "drop"

Data<- MinutesPlayed[1,,drop = FALSE] #only three rows
matplot(t(Data), type="b", pch= 15:18,col=c(1:4,6))

#Let's try to make a legend only for first three players

legend("bottomleft", inset= 0.01, legend=Players [1:3], col=c(1:4,6),pch=15:18, horiz= F)

# %% [markdown]
# Here we can see we have successfully plotted the graph for 1 player using the "drop" feature

# %% [markdown]
# ## Creating a function

# %% [markdown]
# As we have seen from the graph above that everytimeif we want to plot a matrix we have to declare it again and type the whole thing again. so an easy way to do this is to make a function

# %%
myplot <- function()
    
    {
      
         Data<- MinutesPlayed[1,,drop= FALSE] 
         matplot(t(Data), type="b", pch= 15:18,col=c(1:4,6))
         legend("bottomleft", inset= 0.01, legend=Players [1], col=c(1:4,6),pch=15:18, horiz= F)

    
    
}

myplot()  #calling our function

# %%
#As we can see our function is non-dynamic which means we have to change the values everytime acc. to need.

#We can solve this by passing the parameters to the function

myplot <- function(data,rows)
    
    {
      
         Data<- data[rows,,drop= FALSE] 
         matplot(t(Data), type="b", pch= 15:18,col=c(1:4,6))
         legend("bottomleft", inset= 0.01, legend=Players [rows], col=c(1:4,6),pch=15:18, horiz= F)

    
    
}

myplot(MinutesPlayed,1:5)  #passing the value to our function

# %%
#we can also assign default parameters


myplot <- function(data,rows=1:10) #we want all rows from 1 to 10
    
    {
      
         Data<- data[rows,,drop= FALSE] 
         matplot(t(Data), type="b", pch= 15:18,col=c(1:4,6))
         legend("bottomleft", inset= 0.01, legend=Players [rows], col=c(1:4,6),pch=15:18, horiz= F)

    
    
}

myplot(MinutesPlayed)  #now our function will automatically plot all rows from 1 to 10

# %% [markdown]
# ## Homework : Basketball Free Throws

# %%
#Dear Student,
#
#Welcome to the dataset for the homework exercise.
#
#Instructions for this dataset:
# You have only been supplied vectors. You will need
# to create the matrices yourself.
# Matrices:
# - FreeThrows
# - FreeThrowAttempts
#
#Sincerely,
#Kirill Eremenko
#www.superdatascience.com

#Copyright: These datasets were prepared using publicly available data.
#           However, theses scripts are subject to Copyright Laws. 
#           If you wish to use these R scripts outside of the R Programming Course
#           by Kirill Eremenko, you may do so by referencing www.superdatascience.com in your work.

#Comments:
#Seasons are labeled based on the first year in the season
#E.g. the 2012-2013 season is preseneted as simply 2012

#Notes and Corrections to the data:
#Kevin Durant: 2006 - College Data Used
#Kevin Durant: 2005 - Proxied With 2006 Data
#Derrick Rose: 2012 - Did Not Play
#Derrick Rose: 2007 - College Data Used
#Derrick Rose: 2006 - Proxied With 2007 Data
#Derrick Rose: 2005 - Proxied With 2007 Data

#Seasons
Seasons <- c("2005","2006","2007","2008","2009","2010","2011","2012","2013","2014")

#Players
Players <- c("KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade")

#Free Throws
KobeBryant_FT <- c(696,667,623,483,439,483,381,525,18,196)
JoeJohnson_FT <- c(261,235,316,299,220,195,158,132,159,141)
LeBronJames_FT <- c(601,489,549,594,593,503,387,403,439,375)
CarmeloAnthony_FT <- c(573,459,464,371,508,507,295,425,459,189)
DwightHoward_FT <- c(356,390,529,504,483,546,281,355,349,143)
ChrisBosh_FT <- c(474,463,472,504,470,384,229,241,223,179)
ChrisPaul_FT <- c(394,292,332,455,161,337,260,286,295,289)
KevinDurant_FT <- c(209,209,391,452,756,594,431,679,703,146)
DerrickRose_FT <- c(146,146,146,197,259,476,194,0,27,152)
DwayneWade_FT <- c(629,432,354,590,534,494,235,308,189,284)
#Matrix
#
FreeThrows <- rbind(KobeBryant_FT, JoeJohnson_FT, LeBronJames_FT, CarmeloAnthony_FT, DwightHoward_FT, ChrisBosh_FT, ChrisPaul_FT, KevinDurant_FT, DerrickRose_FT, DwayneWade_FT)
rm(KobeBryant_FT, JoeJohnson_FT, CarmeloAnthony_FT, DwightHoward_FT, ChrisBosh_FT, LeBronJames_FT, ChrisPaul_FT, DerrickRose_FT, DwayneWade_FT, KevinDurant_FT)
colnames(FreeThrows) <- Seasons
rownames(FreeThrows) <- Players


#

#Free Throw Attempts
KobeBryant_FTA <- c(819,768,742,564,541,583,451,626,21,241)
JoeJohnson_FTA <- c(330,314,379,362,269,243,186,161,195,176)
LeBronJames_FTA <- c(814,701,771,762,773,663,502,535,585,528)
CarmeloAnthony_FTA <- c(709,568,590,468,612,605,367,512,541,237)
DwightHoward_FTA <- c(598,666,897,849,816,916,572,721,638,271)
ChrisBosh_FTA <- c(581,590,559,617,590,471,279,302,272,232)
ChrisPaul_FTA <- c(465,357,390,524,190,384,302,323,345,321)
KevinDurant_FTA <- c(256,256,448,524,840,675,501,750,805,171)
DerrickRose_FTA <- c(205,205,205,250,338,555,239,0,32,187)
DwayneWade_FTA <- c(803,535,467,771,702,652,297,425,258,370)
#Matrix
#
FreeThrowAttempts <- rbind(KobeBryant_FTA, JoeJohnson_FTA, LeBronJames_FTA, CarmeloAnthony_FTA, DwightHoward_FTA, ChrisBosh_FTA, ChrisPaul_FTA, KevinDurant_FTA, DerrickRose_FTA, DwayneWade_FTA)
rm(KobeBryant_FTA, JoeJohnson_FTA, CarmeloAnthony_FTA, DwightHoward_FTA, ChrisBosh_FTA, LeBronJames_FTA, ChrisPaul_FTA, DerrickRose_FTA, DwayneWade_FTA, KevinDurant_FTA)
colnames(FreeThrowAttempts) <- Seasons
rownames(FreeThrowAttempts) <- Players
#
FreeThrows
FreeThrowAttempts
# Out:
#                2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# KobeBryant     696  667  623  483  439  483  381  525   18  196
# JoeJohnson     261  235  316  299  220  195  158  132  159  141
# LeBronJames    601  489  549  594  593  503  387  403  439  375
# CarmeloAnthony 573  459  464  371  508  507  295  425  459  189
# DwightHoward   356  390  529  504  483  546  281  355  349  143
# ChrisBosh      474  463  472  504  470  384  229  241  223  179
# ChrisPaul      394  292  332  455  161  337  260  286  295  289
# KevinDurant    209  209  391  452  756  594  431  679  703  146
# DerrickRose    146  146  146  197  259  476  194    0   27  152
# DwayneWade     629  432  354  590  534  494  235  308  189  284
#                2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# KobeBryant     819  768  742  564  541  583  451  626   21  241
# JoeJohnson     330  314  379  362  269  243  186  161  195  176
# LeBronJames    814  701  771  762  773  663  502  535  585  528
# ...

# %%
#Re-create the plotting function
myplot <- function(z, who=1:10) {
  matplot(t(z[who,,drop=F]), type="b", pch=15:18, col=c(1:4,6), main="Basketball Players Analysis")
  legend("bottomleft", inset=0.01, legend=Players[who], col=c(1:4,6), pch=15:18, horiz=F)
}

#Visualize the new matrices
myplot(FreeThrows)
myplot(FreeThrowAttempts)

#Part 1 - Free Throw Attempts Per Game 
#(You will need the Games matrix)
myplot(FreeThrowAttempts/Games)
#Notice how Chris Paul gets few attempts per game

#Part 2 - Free Throw Accuracy
myplot(FreeThrows/FreeThrowAttempts)
#And yet Chris Paul's accuracy is one of the highest
#Chances are his team would get more points if he had more FTA's
#Also notice that Dwight Howard's FT Accuracy is extremely poor
#compared to other players. If you recall, Dwight Howard's
#Field Goal Accuracy was exceptional:
myplot(FieldGoals/FieldGoalAttempts)
#How could this be? Why is there such a drastic difference?
#We will see just now...

#Part 3 - Player Style Patterns Excluding Free Throws
myplot((Points-FreeThrows)/FieldGoals)
#Because we have excluded free throws, this plot now shows us
#the true representation of player style change. We can verify
#that this is the case because all the marks without exception
#on this plot are between 2 and 3. That is because Field Goals
#can only be for either 2 points or 3 points.
#Insights:
#1. You can see how players' preference for 2 or 3 point shots
#   changes throughout their career. We can see that almost all
#   players in this dataset experiment with their style throughout
#   their careers. Perhaps, the most drastic change in style has
#   been experienced by Joe Johnson.
#2. There is one exception. You can see that one player has not
#   changed his style at all - almost always scoring only 2-pointers.
#   Who is this mystert player? It's Dwight Howard! 
#   Now that explains a lot. The reason that Dwight Howard's
#   Field Goal accuracy is so good is because he almost always
#   scores 2-pointers only. That means he can be close to the basket
#   or even in contact with it. Free throws, on the other hand require
#   the player to stand 15ft (4.57m) away from the hoop. That's 
#   probably why Dwight Howard's Free Throw Accuracy is poor.
